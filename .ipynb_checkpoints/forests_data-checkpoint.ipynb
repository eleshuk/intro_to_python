# %%
import pandas as pd
import matplotlib as plt
from plotnine import ggplot, aes, geom_point, geom_line, theme_bw, geom_bar

# %%
# Load data
path = "/Users/eleshuk/Documents/GitHub/intro_to_python/data/forestfires.csv"
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
df.dtypes
# Out:
# X          int64
# Y          int64
# month     object
# day       object
# FFMC     float64
# DMC      float64
# DC       float64
# ISI      float64
# temp     float64
# RH         int64
# wind     float64
# rain     float64
# area     float64
# dtype: object

# %%
# df.shape[0]

# %%
# df[['month', 'day']]

# %%
fires_21_24 = df[(df['temp'] > 20) & (df['temp'] < 25)]

# %%
fires_21_24.plot(x = "month", y = ["temp"])
# Out:
# <Axes: xlabel='month'>

# %%
(ggplot(fires_21_24, aes(x='month', y='temp'))
 + geom_point()
+ theme_bw())
# (ggplot(df, aes(x='month', y='temp'))
#  + geom_bar(stat='identity'))

# %%
df.iloc[0:20, 4:8]
# Out:
#     FFMC    DMC     DC   ISI
# 0   86.2   26.2   94.3   5.1
# 1   90.6   35.4  669.1   6.7
# 2   90.6   43.7  686.9   6.7
# 3   91.7   33.3   77.5   9.0
# 4   89.3   51.3  102.2   9.6
# 5   92.3   85.3  488.0  14.7
# 6   92.3   88.9  495.6   8.5
# 7   91.5  145.4  608.2  10.7
# 8   91.0  129.5  692.6   7.0
# 9   92.5   88.0  698.6   7.1
# 10  92.5   88.0  698.6   7.1
# 11  92.8   73.2  713.0  22.6
# 12  63.5   70.8  665.3   0.8
# 13  90.9  126.5  686.5   7.0
# 14  92.9  133.3  699.6   9.2
# 15  93.3  141.2  713.9  13.9
# 16  91.7   35.8   80.8   7.8
# 17  84.9   32.8  664.2   3.0
# 18  89.2   27.9   70.8   6.3
# 19  86.3   27.4   97.1   5.1

# %%
df.loc[df['month'].isin(['aug'])]
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 5    8  6   aug  sun  92.3   85.3  488.0  14.7  22.2  29   5.4   0.0   0.00
# 6    8  6   aug  mon  92.3   88.9  495.6   8.5  24.1  27   3.1   0.0   0.00
# 7    8  6   aug  mon  91.5  145.4  608.2  10.7   8.0  86   2.2   0.0   0.00
# 12   6  5   aug  fri  63.5   70.8  665.3   0.8  17.0  72   6.7   0.0   0.00
# 23   7  4   aug  sat  90.2  110.9  537.4   6.2  19.5  43   5.8   0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 511  8  6   aug  sun  81.6   56.7  665.6   1.9  27.8  35   2.7   0.0   0.00
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
#
# [184 rows x 13 columns]

# %%
# This only accepts one argument
df.columns.get_loc('temp')
# Out:
# 8

# %%
# Use this when you want the index for more than one column 
df.columns.get_indexer(['temp', 'month'])
# Out:
# array([8, 2])

# %%
# df.loc[df.index[0:20], ['month', 'temp']]

# %%
# Reset all values so that all values that are greater than 30 are replaced with 30
# df.loc[df['temp'] > 30, 'temp'] = 30

# %%
df.loc[df['temp'] == 30, 'temp']
# Out:
# Series([], Name: temp, dtype: float64)

# %%
df['temp_f'] = (df['temp'] * 9/5) + 32

# %%
df.to_excel("updated_file.xlsx", sheet_name="fires", index=False)

# %%
updated_df = pd.read_excel("updated_file.xlsx", sheet_name="fires")

# %%
updated_df.plot(x = "month", y = ["temp", "temp_f"])
# Out:
# <Axes: xlabel='month'>

# %%
max_temp = df['temp'].max()
max_temp
# Out:
# np.float64(33.3)
